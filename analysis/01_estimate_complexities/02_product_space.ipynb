# %%
# Our experimental complexities need to run over a network (Product Space)
# How to build a Product Space is far from trivial
# The following is inspired by the original Product Space of the Atlas but uses methods statistically more sound
import sys
import pandas as pd
import networkx as nx
sys.path.append("../..")
from libraries import backboning as bb

# %%
# The Product Space is based on the MCP_exp matrix
# We binarize it to be consistent with how we calculate complexities
# We start with RCA then later we'll do RPOP as well
mcp_exp = pd.read_csv("../../data/processed/mcp_exp.csv", sep = "\t", dtype = {"prod": str})
mcp_rca = pd.pivot_table(data = mcp_exp, index = "prod", columns = "exporter", values = "rca").fillna(0.0) >= 1
mcp_rca
# Out:
# exporter    ABW    AFG    AGO    ALB    ARE    ARG    ARM    AUS    AUT  \
# prod
# 0101      False  False  False  False   True   True  False   True  False
# 0102      False   True  False  False  False  False  False   True   True
# 0103      False  False  False  False  False  False  False  False  False
# 0104      False  False  False  False  False  False   True   True  False
# 0105      False  False  False  False  False  False  False  False   True
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9618      False  False  False  False  False  False  False  False  False
# 9701      False  False  False  False  False  False  False  False   True
# 9703      False  False  False  False  False  False  False  False  False
# 9705      False   True  False   True  False  False  False  False   True
# 9706      False   True  False  False  False  False  False  False   True
#
# exporter    AZE  ...    URY    USA    UZB    VEN    VGB    VNM    YEM    ZAF  \
# prod             ...
# 0101      False  ...   True   True  False  False  False  False  False  False
# 0102      False  ...   True  False  False  False  False  False  False  False
# 0103      False  ...  False  False  False  False  False  False  False  False
# 0104      False  ...   True  False  False  False  False  False  False  False
# 0105      False  ...  False  False  False  False  False  False  False  False
# ...         ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9618      False  ...  False  False  False  False  False   True  False  False
# 9701      False  ...  False   True  False  False   True  False  False  False
# 9703      False  ...  False   True  False  False   True  False  False  False
# 9705      False  ...  False   True  False  False   True  False  False   True
# 9706      False  ...  False   True   True  False   True  False  False  False
#
# exporter    ZMB    ZWE
# prod
# 0101      False  False
# 0102      False  False
# 0103      False  False
# 0104      False  False
# 0105       True   True
# ...         ...    ...
# 9618      False  False
# 9701      False  False
# 9703      False   True
# 9705       True   True
# 9706      False  False
#
# [994 rows x 164 columns]

# %%
# My backboning library requires a pandas dataframe that is not triangular, even if the network is undirected
# The adjacency matrix should be weighted with the count of common exporter for each products
# This is easily achieved via dot product
ps = mcp_rca.astype(int).dot(mcp_rca.astype(int).T)
ps = ps.unstack()
# The library wants the columns to be called src, trg, and nij (the latter is the weight column)
ps.index.names = ("src", "trg")
ps = ps.reset_index().rename(columns = {0: "nij"})
# Throw away self loops
ps = ps[ps["src"] != ps["trg"]]
# Throw away empty links (products pairs without co-exporters)
ps = ps[ps["nij"] > 0]
ps
# Out:
#          src   trg  nij
# 1       0101  0102    9
# 2       0101  0103    5
# 3       0101  0104    5
# 4       0101  0105    7
# 5       0101  0106    9
# ...      ...   ...  ...
# 988029  9706  9616    1
# 988031  9706  9618    4
# 988032  9706  9701    8
# 988033  9706  9703    8
# 988034  9706  9705   16
#
# [947110 rows x 3 columns]

# %%
# Calculate the backbone scores for each link using the noise corrected method
# Method described in https://arxiv.org/abs/1701.07336
ps_nc = bb.noise_corrected(ps, undirected = True, calculate_p_value = True)

# We need to find a reasonable threshold to say that an edge is statistically significant
# This is tricky because we also want every product to have at least a link
# and we also want the Product Space to be a single connected component

# First we start by saying that we only want links with a p-value < 0.01
ps_nc_bb = bb.thresholding(ps_nc, 0.99)
ps_nc_bb
# Out:
# Calculating NC score...
#          src   trg  nij     score
# 997     0102  0104   20  0.999976
# 2987    0104  0106   17  0.999319
# 6       0101  0201   13  0.999484
# 1000    0102  0201   20  0.998815
# 7       0101  0202    7  0.993049
# ...      ...   ...  ...       ...
# 905468  8901  9013    3  0.994506
# 913420  9001  9013    3  0.996665
# 914414  9002  9013    3  0.997031
# 920378  9010  9013    2  0.995481
# 921372  9011  9013    2  0.993979
#
# [8629 rows x 4 columns]

# %%
# Now we need to keep track of all products that don't have a link and the number of connected components in the Product Space
products = set(mcp_exp["prod"])
G = nx.from_pandas_edgelist(ps_nc_bb, source = "src", target = "trg", edge_attr = ("nij", "score"))
missing_products = products - set(G.nodes)
G_comps = list(nx.connected_components(G))
print("Products without a link:")
print(missing_products)
print(f"Connected components: {len(G_comps)}")
# Out:
# Products without a link:
# {'3209', '8476', '3918', '9406', '3214', '5601', '7325', '1518', '8212', '2403', '6905', '2833', '3405', '7412', '4006', '7604', '6914', '7606', '0408', '6810', '3210', '8405', '7413', '3005', '8478', '8546', '3917', '4010', '7019', '5107', '2104', '4901', '8309', '7010', '2309', '2206', '8426', '3814', '6809', '2105', '8436', '4808', '3505', '4902', '3402', '3208', '4012', '8404', '7310', '1806', '8449', '1702', '5404', '7308', '8417', '4821', '2839', '4818', '8425', '2522', '3923', '9602', '5907', '3816', '6902', '5602', '7311', '4805', '9304', '3909', '7612', '7307', '7608', '2904', '3920', '4807', '7005', '7324', '7609', '8703', '4817', '3307', '4811', '3406', '3305', '3809', '3926', '4008', '3921', '2003'}
# Connected components: 3

# %%
# We keep adding edges until we have a single connected components and no product has zero links
while len(G_comps) > 1 or len(missing_products) > 0:
    # First we need to know in which component each node is
    node2comp = {}
    for node in products:
        for i, c in enumerate(G_comps):
            _ = [i for i, c in enumerate(G_comps) if node in c]
            if len(_) == 0:
                # Isolated nodes are in a component identifid by their own code
                node2comp[node] = node
            else:
                # Nodes in a component get the component id
                node2comp[node] = _[0]
    # Assign component id to the nodes
    ps_nc["comp_src"] = ps_nc["src"].map(node2comp)
    ps_nc["comp_trg"] = ps_nc["trg"].map(node2comp)
    # We pick the most significant edge that connects two nodes in different components
    # This unifies the two components and/or reduces the number of isolated nodes
    new_edge = ps_nc[ps_nc["comp_src"] != ps_nc["comp_trg"]].sort_values(by = "score").iloc[-1]
    # Add the edge to the Product Space
    G.add_edge(new_edge["src"], new_edge["trg"], nij = new_edge["nij"], score = new_edge["score"])
    # Update the stopping conditions
    G_comps = list(nx.connected_components(G))
    missing_products = products - set(G.nodes)
    print(f"Connected components: {len(G_comps)}, Missing product count: {len(missing_products)}")
# Out:
# Connected components: 3, Missing product count: 89
# Connected components: 3, Missing product count: 88
# Connected components: 3, Missing product count: 87
# Connected components: 3, Missing product count: 86
# Connected components: 3, Missing product count: 85
# Connected components: 3, Missing product count: 84
# Connected components: 3, Missing product count: 83
# Connected components: 3, Missing product count: 82
# Connected components: 3, Missing product count: 81
# Connected components: 3, Missing product count: 80
# Connected components: 3, Missing product count: 79
# Connected components: 3, Missing product count: 78
# Connected components: 3, Missing product count: 77
# Connected components: 3, Missing product count: 76
# Connected components: 3, Missing product count: 75
# Connected components: 3, Missing product count: 74
# Connected components: 3, Missing product count: 73
# Connected components: 3, Missing product count: 72
# Connected components: 3, Missing product count: 71
# Connected components: 4, Missing product count: 69
# Connected components: 4, Missing product count: 68
# Connected components: 4, Missing product count: 67
# Connected components: 4, Missing product count: 66
# Connected components: 4, Missing product count: 65
# Connected components: 4, Missing product count: 64
# Connected components: 4, Missing product count: 63
# Connected components: 4, Missing product count: 62
# Connected components: 4, Missing product count: 61
# Connected components: 4, Missing product count: 60
# Connected components: 4, Missing product count: 59
# Connected components: 4, Missing product count: 58
# Connected components: 5, Missing product count: 56
# Connected components: 5, Missing product count: 55
# Connected components: 5, Missing product count: 54
# Connected components: 6, Missing product count: 52
# Connected components: 6, Missing product count: 51
# Connected components: 6, Missing product count: 50
# Connected components: 6, Missing product count: 49
# Connected components: 6, Missing product count: 48
# Connected components: 6, Missing product count: 47
# Connected components: 6, Missing product count: 46
# Connected components: 6, Missing product count: 45
# Connected components: 5, Missing product count: 45
# Connected components: 5, Missing product count: 44
# Connected components: 5, Missing product count: 43
# Connected components: 5, Missing product count: 42
# Connected components: 5, Missing product count: 41
# Connected components: 5, Missing product count: 40
# Connected components: 5, Missing product count: 39
# Connected components: 5, Missing product count: 38
# Connected components: 5, Missing product count: 37
# Connected components: 5, Missing product count: 36
# Connected components: 5, Missing product count: 35
# Connected components: 5, Missing product count: 34
# Connected components: 5, Missing product count: 33
# Connected components: 5, Missing product count: 32
# Connected components: 5, Missing product count: 31
# Connected components: 5, Missing product count: 30
# Connected components: 5, Missing product count: 29
# Connected components: 5, Missing product count: 28
# Connected components: 5, Missing product count: 27
# Connected components: 5, Missing product count: 26
# Connected components: 5, Missing product count: 25
# Connected components: 4, Missing product count: 25
# Connected components: 4, Missing product count: 24
# Connected components: 4, Missing product count: 23
# Connected components: 4, Missing product count: 22
# Connected components: 4, Missing product count: 21
# Connected components: 4, Missing product count: 20
# Connected components: 4, Missing product count: 19
# Connected components: 4, Missing product count: 18
# Connected components: 3, Missing product count: 18
# Connected components: 2, Missing product count: 18
# Connected components: 2, Missing product count: 17
# Connected components: 1, Missing product count: 17
# Connected components: 1, Missing product count: 16
# Connected components: 1, Missing product count: 15
# Connected components: 1, Missing product count: 14
# Connected components: 1, Missing product count: 13
# Connected components: 1, Missing product count: 12
# Connected components: 1, Missing product count: 11
# Connected components: 1, Missing product count: 10
# Connected components: 1, Missing product count: 9
# Connected components: 1, Missing product count: 8
# Connected components: 1, Missing product count: 7
# Connected components: 1, Missing product count: 6
# Connected components: 1, Missing product count: 5
# Connected components: 1, Missing product count: 4
# Connected components: 1, Missing product count: 3
# Connected components: 1, Missing product count: 2
# Connected components: 1, Missing product count: 1
# Connected components: 1, Missing product count: 0

# %%
# Now we have a Product Space with p < 0.01 edges, except the ones tying it together in a single component
# This is based on RCA, so let's name it accordingly
nx.write_edgelist(G, "ps_nc_bb_0.01_rca.csv", delimiter = "\t", data = ["nij", "score"])

# %%
# And now we do it all again, but for RPOP instead of RCA
# Maybe this should be a utility function
mcp_rpop = pd.pivot_table(data = mcp_exp, index = "prod", columns = "exporter", values = "rpop").fillna(0.0) >= 0.25

ps = mcp_rpop.astype(int).dot(mcp_rpop.astype(int).T)
ps = ps.unstack()
ps.index.names = ("src", "trg")
ps = ps.reset_index().rename(columns = {0: "nij"})
ps = ps[ps["src"] != ps["trg"]]
ps = ps[ps["nij"] > 0]

ps_nc = bb.noise_corrected(ps, undirected = True, calculate_p_value = True)

# We start with a much lower significance threshold (0.9 instead of 0.99)
# Because RPOP edges seem to be much more noisy...
ps_nc_bb = bb.thresholding(ps_nc, 0.9)

products = set(mcp_exp["prod"])
G = nx.from_pandas_edgelist(ps_nc_bb, source = "src", target = "trg", edge_attr = ("nij", "score"))
missing_products = products - set(G.nodes)
G_comps = list(nx.connected_components(G))

while len(G_comps) > 1 or len(missing_products) > 0:
    node2comp = {}
    for node in products:
        for i, c in enumerate(G_comps):
            _ = [i for i, c in enumerate(G_comps) if node in c]
            if len(_) == 0:
                node2comp[node] = node
            else:
                node2comp[node] = _[0]
    ps_nc["comp_src"] = ps_nc["src"].map(node2comp)
    ps_nc["comp_trg"] = ps_nc["trg"].map(node2comp)
    new_edge = ps_nc[ps_nc["comp_src"] != ps_nc["comp_trg"]].sort_values(by = "score").iloc[-1]
    G.add_edge(new_edge["src"], new_edge["trg"], nij = new_edge["nij"], score = new_edge["score"])
    G_comps = list(nx.connected_components(G))
    missing_products = products - set(G.nodes)
    print(f"Connected components: {len(G_comps)}, Missing product count: {len(missing_products)}")

nx.write_edgelist(G, "ps_nc_bb_0.1_rpop.csv", delimiter = "\t", data = ["nij", "score"])
# Out:
# Calculating NC score...
# Connected components: 7, Missing product count: 352
# Connected components: 7, Missing product count: 351
# Connected components: 7, Missing product count: 350
# Connected components: 7, Missing product count: 349
# Connected components: 7, Missing product count: 348
# Connected components: 7, Missing product count: 347
# Connected components: 7, Missing product count: 346
# Connected components: 8, Missing product count: 344
# Connected components: 7, Missing product count: 344
# Connected components: 7, Missing product count: 343
# Connected components: 7, Missing product count: 342
# Connected components: 7, Missing product count: 341
# Connected components: 7, Missing product count: 340
# Connected components: 7, Missing product count: 339
# Connected components: 7, Missing product count: 338
# Connected components: 7, Missing product count: 337
# Connected components: 7, Missing product count: 336
# Connected components: 7, Missing product count: 335
# Connected components: 7, Missing product count: 334
# Connected components: 8, Missing product count: 332
# Connected components: 8, Missing product count: 331
# Connected components: 8, Missing product count: 330
# Connected components: 8, Missing product count: 329
# Connected components: 8, Missing product count: 328
# Connected components: 8, Missing product count: 327
# Connected components: 8, Missing product count: 326
# Connected components: 8, Missing product count: 325
# Connected components: 8, Missing product count: 324
# Connected components: 8, Missing product count: 323
# Connected components: 8, Missing product count: 322
# Connected components: 8, Missing product count: 321
# Connected components: 8, Missing product count: 320
# Connected components: 8, Missing product count: 319
# Connected components: 7, Missing product count: 319
# Connected components: 7, Missing product count: 318
# Connected components: 7, Missing product count: 317
# Connected components: 6, Missing product count: 317
# Connected components: 6, Missing product count: 316
# Connected components: 6, Missing product count: 315
# Connected components: 6, Missing product count: 314
# Connected components: 5, Missing product count: 314
# Connected components: 5, Missing product count: 313
# Connected components: 5, Missing product count: 312
# Connected components: 6, Missing product count: 310
# Connected components: 6, Missing product count: 309
# Connected components: 6, Missing product count: 308
# Connected components: 6, Missing product count: 307
# Connected components: 6, Missing product count: 306
# Connected components: 6, Missing product count: 305
# Connected components: 6, Missing product count: 304
# Connected components: 6, Missing product count: 303
# Connected components: 7, Missing product count: 301
# Connected components: 6, Missing product count: 301
# Connected components: 6, Missing product count: 300
# Connected components: 6, Missing product count: 299
# Connected components: 7, Missing product count: 297
# Connected components: 7, Missing product count: 296
# Connected components: 7, Missing product count: 295
# Connected components: 7, Missing product count: 294
# Connected components: 7, Missing product count: 293
# Connected components: 7, Missing product count: 292
# Connected components: 7, Missing product count: 291
# Connected components: 7, Missing product count: 290
# Connected components: 7, Missing product count: 289
# Connected components: 7, Missing product count: 288
# Connected components: 7, Missing product count: 287
# Connected components: 7, Missing product count: 286
# Connected components: 7, Missing product count: 285
# Connected components: 7, Missing product count: 284
# Connected components: 7, Missing product count: 283
# Connected components: 6, Missing product count: 283
# Connected components: 6, Missing product count: 282
# Connected components: 6, Missing product count: 281
# Connected components: 6, Missing product count: 280
# Connected components: 6, Missing product count: 279
# Connected components: 6, Missing product count: 278
# Connected components: 6, Missing product count: 277
# Connected components: 6, Missing product count: 276
# Connected components: 6, Missing product count: 275
# Connected components: 6, Missing product count: 274
# Connected components: 6, Missing product count: 273
# Connected components: 6, Missing product count: 272
# Connected components: 7, Missing product count: 270
# Connected components: 7, Missing product count: 269
# Connected components: 7, Missing product count: 268
# Connected components: 7, Missing product count: 267
# Connected components: 7, Missing product count: 266
# Connected components: 7, Missing product count: 265
# Connected components: 8, Missing product count: 263
# Connected components: 8, Missing product count: 262
# Connected components: 8, Missing product count: 261
# Connected components: 8, Missing product count: 260
# Connected components: 7, Missing product count: 260
# Connected components: 7, Missing product count: 259
# Connected components: 7, Missing product count: 258
# Connected components: 8, Missing product count: 256
# Connected components: 8, Missing product count: 255
# Connected components: 7, Missing product count: 255
# Connected components: 7, Missing product count: 254
# Connected components: 6, Missing product count: 254
# Connected components: 6, Missing product count: 253
# Connected components: 6, Missing product count: 252
# Connected components: 6, Missing product count: 251
# Connected components: 6, Missing product count: 250
# Connected components: 6, Missing product count: 249
# Connected components: 7, Missing product count: 247
# Connected components: 7, Missing product count: 246
# Connected components: 7, Missing product count: 245
# Connected components: 6, Missing product count: 245
# Connected components: 6, Missing product count: 244
# Connected components: 6, Missing product count: 243
# Connected components: 6, Missing product count: 242
# Connected components: 6, Missing product count: 241
# Connected components: 6, Missing product count: 240
# Connected components: 6, Missing product count: 239
# Connected components: 6, Missing product count: 238
# Connected components: 6, Missing product count: 237
# Connected components: 6, Missing product count: 236
# Connected components: 6, Missing product count: 235
# Connected components: 6, Missing product count: 234
# Connected components: 6, Missing product count: 233
# Connected components: 6, Missing product count: 232
# Connected components: 6, Missing product count: 231
# Connected components: 6, Missing product count: 230
# Connected components: 6, Missing product count: 229
# Connected components: 6, Missing product count: 228
# Connected components: 6, Missing product count: 227
# Connected components: 6, Missing product count: 226
# Connected components: 6, Missing product count: 225
# Connected components: 6, Missing product count: 224
# Connected components: 6, Missing product count: 223
# Connected components: 5, Missing product count: 223
# Connected components: 5, Missing product count: 222
# Connected components: 5, Missing product count: 221
# Connected components: 5, Missing product count: 220
# Connected components: 5, Missing product count: 219
# Connected components: 5, Missing product count: 218
# Connected components: 5, Missing product count: 217
# Connected components: 5, Missing product count: 216
# Connected components: 5, Missing product count: 215
# Connected components: 5, Missing product count: 214
# Connected components: 5, Missing product count: 213
# Connected components: 5, Missing product count: 212
# Connected components: 4, Missing product count: 212
# Connected components: 4, Missing product count: 211
# Connected components: 4, Missing product count: 210
# Connected components: 4, Missing product count: 209
# Connected components: 4, Missing product count: 208
# Connected components: 4, Missing product count: 207
# Connected components: 4, Missing product count: 206
# Connected components: 4, Missing product count: 205
# Connected components: 4, Missing product count: 204
# Connected components: 4, Missing product count: 203
# Connected components: 4, Missing product count: 202
# Connected components: 4, Missing product count: 201
# Connected components: 5, Missing product count: 199
# Connected components: 5, Missing product count: 198
# Connected components: 5, Missing product count: 197
# Connected components: 5, Missing product count: 196
# Connected components: 5, Missing product count: 195
# Connected components: 5, Missing product count: 194
# Connected components: 5, Missing product count: 193
# Connected components: 4, Missing product count: 193
# Connected components: 4, Missing product count: 192
# Connected components: 4, Missing product count: 191
# Connected components: 4, Missing product count: 190
# Connected components: 4, Missing product count: 189
# Connected components: 4, Missing product count: 188
# Connected components: 4, Missing product count: 187
# Connected components: 4, Missing product count: 186
# Connected components: 4, Missing product count: 185
# Connected components: 4, Missing product count: 184
# Connected components: 4, Missing product count: 183
# Connected components: 4, Missing product count: 182
# Connected components: 4, Missing product count: 181
# Connected components: 4, Missing product count: 180
# Connected components: 4, Missing product count: 179
# Connected components: 4, Missing product count: 178
# Connected components: 4, Missing product count: 177
# Connected components: 3, Missing product count: 177
# Connected components: 3, Missing product count: 176
# Connected components: 3, Missing product count: 175
# Connected components: 3, Missing product count: 174
# Connected components: 3, Missing product count: 173
# Connected components: 3, Missing product count: 172
# Connected components: 3, Missing product count: 171
# Connected components: 3, Missing product count: 170
# Connected components: 3, Missing product count: 169
# Connected components: 3, Missing product count: 168
# Connected components: 3, Missing product count: 167
# Connected components: 3, Missing product count: 166
# Connected components: 3, Missing product count: 165
# Connected components: 3, Missing product count: 164
# Connected components: 3, Missing product count: 163
# Connected components: 3, Missing product count: 162
# Connected components: 3, Missing product count: 161
# Connected components: 3, Missing product count: 160
# Connected components: 3, Missing product count: 159
# Connected components: 3, Missing product count: 158
# Connected components: 3, Missing product count: 157
# Connected components: 3, Missing product count: 156
# Connected components: 3, Missing product count: 155
# Connected components: 3, Missing product count: 154
# Connected components: 3, Missing product count: 153
# Connected components: 3, Missing product count: 152
# Connected components: 3, Missing product count: 151
# Connected components: 3, Missing product count: 150
# Connected components: 3, Missing product count: 149
# Connected components: 4, Missing product count: 147
# Connected components: 4, Missing product count: 146
# Connected components: 4, Missing product count: 145
# Connected components: 4, Missing product count: 144
# Connected components: 4, Missing product count: 143
# Connected components: 4, Missing product count: 142
# Connected components: 4, Missing product count: 141
# Connected components: 4, Missing product count: 140
# Connected components: 4, Missing product count: 139
# Connected components: 5, Missing product count: 137
# Connected components: 5, Missing product count: 136
# Connected components: 5, Missing product count: 135
# Connected components: 5, Missing product count: 134
# Connected components: 5, Missing product count: 133
# Connected components: 5, Missing product count: 132
# Connected components: 6, Missing product count: 130
# Connected components: 6, Missing product count: 129
# Connected components: 6, Missing product count: 128
# Connected components: 6, Missing product count: 127
# Connected components: 5, Missing product count: 127
# Connected components: 5, Missing product count: 126
# Connected components: 5, Missing product count: 125
# Connected components: 5, Missing product count: 124
# Connected components: 4, Missing product count: 124
# Connected components: 4, Missing product count: 123
# Connected components: 4, Missing product count: 122
# Connected components: 4, Missing product count: 121
# Connected components: 4, Missing product count: 120
# Connected components: 4, Missing product count: 119
# Connected components: 4, Missing product count: 118
# Connected components: 4, Missing product count: 117
# Connected components: 4, Missing product count: 116
# Connected components: 4, Missing product count: 115
# Connected components: 3, Missing product count: 115
# Connected components: 3, Missing product count: 114
# Connected components: 3, Missing product count: 113
# Connected components: 3, Missing product count: 112
# Connected components: 3, Missing product count: 111
# Connected components: 3, Missing product count: 110
# Connected components: 3, Missing product count: 109
# Connected components: 3, Missing product count: 108
# Connected components: 3, Missing product count: 107
# Connected components: 3, Missing product count: 106
# Connected components: 4, Missing product count: 104
# Connected components: 4, Missing product count: 103
# Connected components: 4, Missing product count: 102
# Connected components: 4, Missing product count: 101
# Connected components: 4, Missing product count: 100
# Connected components: 4, Missing product count: 99
# Connected components: 4, Missing product count: 98
# Connected components: 4, Missing product count: 97
# Connected components: 4, Missing product count: 96
# Connected components: 4, Missing product count: 95
# Connected components: 4, Missing product count: 94
# Connected components: 4, Missing product count: 93
# Connected components: 4, Missing product count: 92
# Connected components: 4, Missing product count: 91
# Connected components: 4, Missing product count: 90
# Connected components: 4, Missing product count: 89
# Connected components: 3, Missing product count: 89
# Connected components: 3, Missing product count: 88
# Connected components: 3, Missing product count: 87
# Connected components: 3, Missing product count: 86
# Connected components: 3, Missing product count: 85
# Connected components: 2, Missing product count: 85
# Connected components: 2, Missing product count: 84
# Connected components: 2, Missing product count: 83
# Connected components: 2, Missing product count: 82
# Connected components: 2, Missing product count: 81
# Connected components: 2, Missing product count: 80
# Connected components: 2, Missing product count: 79
# Connected components: 2, Missing product count: 78
# Connected components: 2, Missing product count: 77
# Connected components: 2, Missing product count: 76
# Connected components: 2, Missing product count: 75
# Connected components: 2, Missing product count: 74
# Connected components: 2, Missing product count: 73
# Connected components: 2, Missing product count: 72
# Connected components: 2, Missing product count: 71
# Connected components: 2, Missing product count: 70
# Connected components: 3, Missing product count: 68
# Connected components: 4, Missing product count: 66
# Connected components: 4, Missing product count: 65
# Connected components: 4, Missing product count: 64
# Connected components: 4, Missing product count: 63
# Connected components: 4, Missing product count: 62
# Connected components: 4, Missing product count: 61
# Connected components: 4, Missing product count: 60
# Connected components: 4, Missing product count: 59
# Connected components: 4, Missing product count: 58
# Connected components: 4, Missing product count: 57
# Connected components: 3, Missing product count: 57
# Connected components: 3, Missing product count: 56
# Connected components: 3, Missing product count: 55
# Connected components: 3, Missing product count: 54
# Connected components: 3, Missing product count: 53
# Connected components: 3, Missing product count: 52
# Connected components: 4, Missing product count: 50
# Connected components: 4, Missing product count: 49
# Connected components: 4, Missing product count: 48
# Connected components: 4, Missing product count: 47
# Connected components: 4, Missing product count: 46
# Connected components: 4, Missing product count: 45
# Connected components: 4, Missing product count: 44
# Connected components: 4, Missing product count: 43
# Connected components: 3, Missing product count: 43
# Connected components: 3, Missing product count: 42
# Connected components: 3, Missing product count: 41
# Connected components: 4, Missing product count: 39
# Connected components: 3, Missing product count: 39
# Connected components: 3, Missing product count: 38
# Connected components: 3, Missing product count: 37
# Connected components: 3, Missing product count: 36
# Connected components: 3, Missing product count: 35
# Connected components: 3, Missing product count: 34
# Connected components: 3, Missing product count: 33
# Connected components: 3, Missing product count: 32
# Connected components: 4, Missing product count: 30
# Connected components: 4, Missing product count: 29
# Connected components: 4, Missing product count: 28
# Connected components: 4, Missing product count: 27
# Connected components: 4, Missing product count: 26
# Connected components: 4, Missing product count: 25
# Connected components: 4, Missing product count: 24
# Connected components: 4, Missing product count: 23
# Connected components: 4, Missing product count: 22
# Connected components: 3, Missing product count: 22
# Connected components: 3, Missing product count: 21
# Connected components: 2, Missing product count: 21
# Connected components: 2, Missing product count: 20
# Connected components: 2, Missing product count: 19
# Connected components: 2, Missing product count: 18
# Connected components: 2, Missing product count: 17
# Connected components: 1, Missing product count: 17
# Connected components: 1, Missing product count: 16
# Connected components: 1, Missing product count: 15
# Connected components: 1, Missing product count: 14
# Connected components: 1, Missing product count: 13
# Connected components: 1, Missing product count: 12
# Connected components: 1, Missing product count: 11
# Connected components: 1, Missing product count: 10
# Connected components: 1, Missing product count: 9
# Connected components: 1, Missing product count: 8
# Connected components: 1, Missing product count: 7
# Connected components: 1, Missing product count: 6
# Connected components: 1, Missing product count: 5
# Connected components: 1, Missing product count: 4
# Connected components: 1, Missing product count: 3
# Connected components: 1, Missing product count: 2
# Connected components: 1, Missing product count: 1
# Connected components: 1, Missing product count: 0
